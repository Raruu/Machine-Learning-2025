# %% [markdown]
# # JS01 - Pengenalan Pembelajaran Mesin
# # Bagian 1
# 1. Buat file notebook dengan nama TG1_NIM_NAMA.ipynb. Contoh: TG_0028119106_M AFIF HENDRAWAN.ipynb.
# 2. Lakukan instalasi library berikut pada notebook,
# <ol type="a">
#   <li>PyPREP</li>
#   <li>Scipy</li>
#   <li>wandb</li>
#   <li>pyECG</li>
# </ol>

# %%
#@markdown pyecg tidak bisa diinstall (google colab): unmaintained, butuh versi python lama python 3.6
# !pip install pyprep scipy wandb
# pyecg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 68.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# 3. Jelaskan kegunakan masing-masing library tersebut.
# ##### PyPREP
# Kegunaan: Library untuk preprocessing data EEG (Electroencephalography)\
# Fungsinya:
# - Deteksi dan koreksi line noise (50/60 Hz)
# - Deteksi bad channels
# - Re-referencing ke robust average reference
# - Filtering adaptif
# - Interpolasi saluran yang bermasalah
#
# ##### SciPy
# Kegunaan: Library fundamental untuk komputasi ilmiah dan teknik\
# Fungsinya:
# - Operasi matematika dan statistik lanjutan
# - Optimasi dan fitting kurva
# - Pemrosesan sinyal (filtering, FFT, dll.)
# - Aljabar linear dan matriks
# - Interpolasi dan integrasi numerik
#
# ##### wandb
# Kegunaan: Platform eksperimen dan experiment tracking untuk machine learning\
# Fungsinya:
# - Melacak metrik, hyperparameter, dan hasil model
# - Visualisasi training progress
# - Versioning model dan dataset
# - Kolaborasi tim dalam proyek ML
# - Logging dan monitoring experiments
#
# ##### pyECG
# Kegunaan: Library untuk analisis sinyal ECG (Electrocardiogram)\
# Fungsinya:
# - Deteksi QRS complex (peaks R-wave)
# - Ekstraksi fitur-fitur ECG
# - Analisis variabilitas detak jantung (HRV)
# - Denoising dan preprocessing sinyal ECG
# - Visualisasi dan interpretasi hasil ECG

# %% [markdown]
# # Bagian 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# > - Kasus: Penyalahgunaan AI untuk membuat dan menyebarkan gambar pornografi palsu menggunakan wajah artis Taylor Swift tanpa izin.<br/> <br/>
# > **Pelanggaran**:
# > - Etika: Melanggar prinsip privasi, dan kemanusiaan dalam penggunaan AI.
# > - Hukum: Pelanggaran terhadap UU Perlindungan Data Pribadi (UU PDP) dikenal dengan “Data biometrik”, No. 27 Tahun 2022, khususnya terkait penggunaan data biometrik (wajah) tanpa persetujuan.
# > - Dampak: Mencederai reputasi korban, menimbulkan trauma, dan memicu keprihatinan publik terhadap keamanan digital.
# > - Referensi: [Upaya Penegakan Etika Hukum Terhadap teknologi Artificial Intelligence Content Generated: Analisis Kasus AI-Generated Fake Pornographic Images](https://law.uii.ac.id/blog/2024/05/02/upaya-penegakan-etika-hukum-terhadap-teknologi-artificial-intelligence-content-generated-analisis-kasus-ai-generated-fake-pornographic-images/)
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
# > - Contoh dampak energi, kebutuhan daya pusat data di Amerika Utara meningkat dari 2.688 megawatt pada akhir 2022 menjadi 5.341 megawatt pada akhir 2023, sebagian didorong oleh permintaan dari kecerdasan buatan generatif (generative AI). Secara global, konsumsi listrik pusat data mencapai 460 terawatt-jam pada 2022.
# > - Contoh dampak lingkungan, pelatihan model AI yang besar seperti GPT-3 dapat menghasilkan emisi hingga 552 ton CO₂ dan juga AI dan pusat data membutuhkan jumlah air yang besar untuk sistem pendinginan, diperkirakan sebanyak 4,2-6,6 miliar meter kubik air pada 2027
# > Referensi:
# > - Referensi: [Explained: Generative AI's environmental impact](https://news.mit.edu/2025/explained-generative-ai-environmental-impact-0117)
# > - Referensi 2: [Penggunaan Teknologi AI Generatif Boros Konsumsi Energi Listrik](https://infokomputer.grid.id/read/124127698/penggunaan-teknologi-ai-generatif-boros-konsumsi-energi-listrik)
# > - Solusi, mengoptimalisasi hardware dan model, misal menggunakan chip yang lebih efisien, membangun infrastruktur yang dapat memanfaatkan panas dan menggunakan energi yang ramah lingkungan
